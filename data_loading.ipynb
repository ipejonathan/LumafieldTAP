# %%
import numpy as np
import nrrd

# %%
readdata, header = nrrd.read(r"C:\Users\Jonathan Ipe\Dropbox\Coding\LumafieldTAP\data\ab-pegasus-longer.nrrd")
print(readdata.shape)
print(header)
# Out:
# (354, 348, 808)
# OrderedDict([('type', 'uint8'), ('dimension', 3), ('sizes', array([354, 348, 808])), ('endian', 'little'), ('encoding', 'gzip'), ('space directions', array([[0., 0., 1.],
#        [0., 1., 0.],
#        [1., 0., 0.]])), ('space origin', array([0., 0., 0.])), ('old min', 0.0), ('old max', 0.02908000325784102)])

# %%
import matplotlib.pyplot as plt
plt.title("Nike Shoe Luminosity Intensities")
plt.hist(readdata.flatten(), bins=100)
plt.xlabel("Intensity"); plt.ylabel("Count"); plt.show()

# %% [markdown]
# ## Generate Point Cloud Representations from STL Files

# %%
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
mesh = o3d.io.read_triangle_mesh(r"C:\Users\Jonathan Ipe\Dropbox\Coding\LumafieldTAP\stl_data\geode\geode-dense.stl")

mesh.compute_vertex_normals()
pcd = mesh.sample_points_uniformly(number_of_points=100000)

o3d.io.write_point_cloud("./point_cloud_data/geode/geode-dense.ply", pcd)

o3d.visualization.draw_geometries_with_editing([pcd])

# %% [markdown]
# ## Visualize Point Clouds from PLY Files

# %%
pcd = o3d.io.read_point_cloud("./point_cloud_data/shoe/shoe-segmented-pointnet.ply")
o3d.visualization.draw_geometries_with_editing([pcd])
